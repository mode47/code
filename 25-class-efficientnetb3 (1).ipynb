# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        pass
        #print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
import random
from PIL import Image
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras import Sequential, Model
from keras.layers import (Conv2D, MaxPooling2D, Dense, Flatten, \
                          Dropout, Input,GlobalAveragePooling2D,BatchNormalization)
from tensorflow.keras.activations import softmax
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from mpl_toolkits.axes_grid1 import ImageGrid
from keras.models import Model
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import (ConfusionMatrixDisplay, confusion_matrix, 
                             accuracy_score)
import cv2
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import os
trainOne=os.listdir('/kaggle/input/skindatasets/skin/train')
trainTow=os.listdir("/kaggle/input/dateset-23-skin/dataset")
cat=trainTow
cat2=['Normal','vitiligo']
def data_dictionary():
    path_trainOne="/kaggle/input/dateset-23-skin/dataset/"
    path_trainTow="/kaggle/input/skindatasets/skin/train/"
    list_train=cat
    list_train1=cat2
    train_dictionary={"image_path":[],"target":[]}
    test_dictionary={"image_path":[],"target":[]}
    k=0
    for i in list_train:
        print(i)
        path_disease_train=path_trainOne+i
        image_list_train=os.listdir(path_disease_train)
        for j in image_list_train:
            img_path_train=path_disease_train+"/"+j   
            train_dictionary["image_path"].append(img_path_train)
            train_dictionary['target'].append(k)
                
        k+=1
    L=23    
    for i in list_train1:
       
        path_disease_test=path_trainTow+i
        image_list_test=os.listdir(path_disease_test)
        for j in image_list_test:
            img_path_train=path_disease_test+"/"+j
            if img_path_train!="/kaggle/input/skindatasets/skin/train/Normal/34.avif":
                
            #print(img_path_train)
                train_dictionary["image_path"].append(img_path_train)
                train_dictionary['target'].append(L)
        L+=1    
          
    train_df=pd.DataFrame(train_dictionary)
    train_df = train_df.groupby("target").head(700) 
    
    return  train_df

# %%
train=data_dictionary()
# Out:
# Light Diseases and Disorders of Pigmentation
# Lupus and other Connective Tissue diseases
# Acne and Rosacea Photos
# Systemic Disease
# Poison Ivy Photos and other Contact Dermatitis
# Vascular Tumors
# Urticaria Hives
# Atopic Dermatitis Photos
# Bullous Disease Photos
# Hair Loss Photos Alopecia and other Hair Diseases
# Tinea Ringworm Candidiasis and other Fungal Infections
# Psoriasis pictures Lichen Planus and related diseases
# Melanoma Skin Cancer Nevi and Moles
# Nail Fungus and other Nail Disease
# Scabies Lyme Disease and other Infestations and Bites
# Eczema Photos
# Exanthems and Drug Eruptions
# Herpes HPV and other STDs Photos
# Seborrheic Keratoses and other Benign Tumors
# Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions
# Vasculitis Photos
# Cellulitis Impetigo and other Bacterial Infections
# Warts Molluscum and other Viral Infections

# %%
import cv2
images=[]
label=[]
for i in train['image_path']:
    img=cv2.imread(i)
    img=cv2.resize(img,(100,100),interpolation=cv2.INTER_AREA)
    img = cv2.normalize(img, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8U)
    #img=resize_and_rescale(img)
    images.append(img)

# %%
label=train['target']

# %%
import numpy as np
import pandas as pd

# %%
data=np.array(images)

# %%
label=np.array(label)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.2,random_state=44)
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=0.2,random_state=1)

# %%
X_train.shape
# Out:
# (11200, 100, 100, 3)

# %%
X_test.shape
# Out:
# (3500, 100, 100, 3)

# %%
import keras
num_classes = 25
y_train = keras.utils.to_categorical(y_train, num_classes)

# %%
y_validation=keras.utils.to_categorical(y_validation, num_classes)

# %%
y_test=keras.utils.to_categorical(y_test, num_classes)

# %%
from tensorflow.keras.applications import  VGG19,EfficientNetB0,VGG16,InceptionV3,ResNet50,EfficientNetB3
from tensorflow.keras.models import Model
from keras.applications.vgg16 import preprocess_input

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.models import Model
# Step 1: Choose a Pre-trained Model
base_model = EfficientNetB3(weights='imagenet', include_top=False, input_shape=(100, 100, 3))
# Step 2: Model Modification
x = base_model.output
x = Flatten()(x)
# x = BatchNormalization()(x)
# x = MaxPooling2D(pool_size=(2, 2))(x)
# x = Flatten()(x)
# x = Dense(256, activation='relu')(x)
# x = BatchNormalization()(x)
# x = Dense(128, activation='relu')(x)
# x = Flatten()(x)
# x = BatchNormalization()(x)
# x = Dense(64, activation='relu')(x)

predictions = Dense(25, activation='softmax')(x)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 [==============================] - 0s 0us/step

# %%
model = Model(inputs=base_model.input, outputs=predictions)
# Step 3: Freeze Pre-trained Layers
for layer in base_model.layers:
    layer.trainable = False

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 100, 100, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 100, 100, 3)  7           ['rescaling[0][0]']
#
#  rescaling_1 (Rescaling)        (None, 100, 100, 3)  0           ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 101, 101, 3)  0           ['rescaling_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 50, 50, 40)   1080        ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 50, 50, 40)   160         ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 50, 50, 40)   0           ['stem_bn[0][0]']
#
#  block1a_dwconv (DepthwiseConv2  (None, 50, 50, 40)  360         ['stem_activation[0][0]']
#  D)
#
#  block1a_bn (BatchNormalization  (None, 50, 50, 40)  160         ['block1a_dwconv[0][0]']
#  )
#
#  block1a_activation (Activation  (None, 50, 50, 40)  0           ['block1a_bn[0][0]']
#  )
#
#  block1a_se_squeeze (GlobalAver  (None, 40)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 40)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 10)     410         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 40)     440         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 50, 50, 40)   0           ['block1a_activation[0][0]',
#                                                                   'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 50, 50, 24)   960         ['block1a_se_excite[0][0]']
#
#  block1a_project_bn (BatchNorma  (None, 50, 50, 24)  96          ['block1a_project_conv[0][0]']
#  lization)
#
#  block1b_dwconv (DepthwiseConv2  (None, 50, 50, 24)  216         ['block1a_project_bn[0][0]']
#  D)
#
#  block1b_bn (BatchNormalization  (None, 50, 50, 24)  96          ['block1b_dwconv[0][0]']
#  )
#
#  block1b_activation (Activation  (None, 50, 50, 24)  0           ['block1b_bn[0][0]']
#  )
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 50, 50, 24)   0           ['block1b_activation[0][0]',
#                                                                   'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 50, 50, 24)   576         ['block1b_se_excite[0][0]']
#
#  block1b_project_bn (BatchNorma  (None, 50, 50, 24)  96          ['block1b_project_conv[0][0]']
#  lization)
#
#  block1b_drop (Dropout)         (None, 50, 50, 24)   0           ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)              (None, 50, 50, 24)   0           ['block1b_drop[0][0]',
#                                                                   'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 50, 50, 144)  3456        ['block1b_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 50, 50, 144)  576        ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 50, 50, 144)  0          ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 51, 51, 144)  0          ['block2a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 25, 25, 144)  1296       ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 25, 25, 144)  576        ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 25, 25, 144)  0          ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 25, 25, 144)  0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 25, 25, 32)   4608        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 25, 25, 32)  128         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 25, 25, 192)  6144        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 25, 25, 192)  768        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 25, 25, 192)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 25, 25, 192)  1728       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 25, 25, 192)  768        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 25, 25, 192)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 192)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 25, 25, 192)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 25, 25, 32)   6144        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 25, 25, 32)  128         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 25, 25, 32)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 25, 25, 32)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 25, 25, 192)  6144        ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 25, 25, 192)  768        ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 25, 25, 192)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 25, 25, 192)  1728       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 25, 25, 192)  768        ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 25, 25, 192)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 192)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 25, 25, 192)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 25, 25, 32)   6144        ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 25, 25, 32)  128         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 25, 25, 32)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 25, 25, 32)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 25, 25, 192)  6144        ['block2c_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 25, 25, 192)  768        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 25, 25, 192)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 29, 29, 192)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 13, 13, 192)  4800       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 13, 13, 192)  768        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 13, 13, 192)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 192)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 13, 13, 192)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 13, 13, 48)   9216        ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 13, 13, 48)  192         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 13, 13, 288)  13824       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 13, 13, 288)  1152       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 13, 13, 288)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 13, 13, 288)  7200       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 13, 13, 288)  1152       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 13, 13, 288)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 288)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 13, 13, 288)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 13, 13, 48)   13824       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 13, 13, 48)  192         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 13, 13, 48)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 13, 13, 48)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 13, 13, 288)  13824       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 13, 13, 288)  1152       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 13, 13, 288)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 13, 13, 288)  7200       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 13, 13, 288)  1152       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 13, 13, 288)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 288)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 13, 13, 288)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 13, 13, 48)   13824       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 13, 13, 48)  192         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 13, 13, 48)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 13, 13, 48)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 13, 13, 288)  13824       ['block3c_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 13, 13, 288)  1152       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 13, 13, 288)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 15, 15, 288)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 7, 7, 288)   2592        ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 7, 7, 288)   1152        ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 7, 7, 288)   0           ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 288)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 7, 7, 288)    0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 7, 7, 96)     27648       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 7, 7, 96)    384         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 7, 7, 576)    55296       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 7, 7, 576)   2304        ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 7, 7, 576)   0           ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 7, 7, 576)   5184        ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 7, 7, 576)   2304        ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 7, 7, 576)   0           ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 576)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 7, 7, 576)    0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 7, 7, 96)     55296       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 7, 7, 96)    384         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 7, 7, 96)     0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 7, 7, 96)     0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 7, 7, 576)    55296       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 7, 7, 576)   2304        ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 7, 7, 576)   0           ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 7, 7, 576)   5184        ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 7, 7, 576)   2304        ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 7, 7, 576)   0           ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 576)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 7, 7, 576)    0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 7, 7, 96)     55296       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 7, 7, 96)    384         ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 7, 7, 96)     0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 7, 7, 96)     0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 7, 7, 576)    55296       ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 7, 7, 576)   2304        ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 7, 7, 576)   0           ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv (DepthwiseConv2  (None, 7, 7, 576)   5184        ['block4d_expand_activation[0][0]
#  D)                                                              ']
#
#  block4d_bn (BatchNormalization  (None, 7, 7, 576)   2304        ['block4d_dwconv[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 7, 7, 576)   0           ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 576)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 7, 7, 576)    0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 7, 7, 96)     55296       ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 7, 7, 96)    384         ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 7, 7, 96)     0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 7, 7, 96)     0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 7, 7, 576)    55296       ['block4d_add[0][0]']
#
#  block4e_expand_bn (BatchNormal  (None, 7, 7, 576)   2304        ['block4e_expand_conv[0][0]']
#  ization)
#
#  block4e_expand_activation (Act  (None, 7, 7, 576)   0           ['block4e_expand_bn[0][0]']
#  ivation)
#
#  block4e_dwconv (DepthwiseConv2  (None, 7, 7, 576)   5184        ['block4e_expand_activation[0][0]
#  D)                                                              ']
#
#  block4e_bn (BatchNormalization  (None, 7, 7, 576)   2304        ['block4e_dwconv[0][0]']
#  )
#
#  block4e_activation (Activation  (None, 7, 7, 576)   0           ['block4e_bn[0][0]']
#  )
#
#  block4e_se_squeeze (GlobalAver  (None, 576)         0           ['block4e_activation[0][0]']
#  agePooling2D)
#
#  block4e_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4e_se_squeeze[0][0]']
#
#  block4e_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4e_se_reshape[0][0]']
# ...
#  ization)
#
#  block6e_expand_activation (Act  (None, 4, 4, 1392)  0           ['block6e_expand_bn[0][0]']
#  ivation)
#
#  block6e_dwconv (DepthwiseConv2  (None, 4, 4, 1392)  34800       ['block6e_expand_activation[0][0]
#  D)                                                              ']
#
#  block6e_bn (BatchNormalization  (None, 4, 4, 1392)  5568        ['block6e_dwconv[0][0]']
#  )
#
#  block6e_activation (Activation  (None, 4, 4, 1392)  0           ['block6e_bn[0][0]']
#  )
#
#  block6e_se_squeeze (GlobalAver  (None, 1392)        0           ['block6e_activation[0][0]']
#  agePooling2D)
#
#  block6e_se_reshape (Reshape)   (None, 1, 1, 1392)   0           ['block6e_se_squeeze[0][0]']
#
#  block6e_se_reduce (Conv2D)     (None, 1, 1, 58)     80794       ['block6e_se_reshape[0][0]']
#
#  block6e_se_expand (Conv2D)     (None, 1, 1, 1392)   82128       ['block6e_se_reduce[0][0]']
#
#  block6e_se_excite (Multiply)   (None, 4, 4, 1392)   0           ['block6e_activation[0][0]',
#                                                                   'block6e_se_expand[0][0]']
#
#  block6e_project_conv (Conv2D)  (None, 4, 4, 232)    322944      ['block6e_se_excite[0][0]']
#
#  block6e_project_bn (BatchNorma  (None, 4, 4, 232)   928         ['block6e_project_conv[0][0]']
#  lization)
#
#  block6e_drop (Dropout)         (None, 4, 4, 232)    0           ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)              (None, 4, 4, 232)    0           ['block6e_drop[0][0]',
#                                                                   'block6d_add[0][0]']
#
#  block6f_expand_conv (Conv2D)   (None, 4, 4, 1392)   322944      ['block6e_add[0][0]']
#
#  block6f_expand_bn (BatchNormal  (None, 4, 4, 1392)  5568        ['block6f_expand_conv[0][0]']
#  ization)
#
#  block6f_expand_activation (Act  (None, 4, 4, 1392)  0           ['block6f_expand_bn[0][0]']
#  ivation)
#
#  block6f_dwconv (DepthwiseConv2  (None, 4, 4, 1392)  34800       ['block6f_expand_activation[0][0]
#  D)                                                              ']
#
#  block6f_bn (BatchNormalization  (None, 4, 4, 1392)  5568        ['block6f_dwconv[0][0]']
#  )
#
#  block6f_activation (Activation  (None, 4, 4, 1392)  0           ['block6f_bn[0][0]']
#  )
#
#  block6f_se_squeeze (GlobalAver  (None, 1392)        0           ['block6f_activation[0][0]']
#  agePooling2D)
#
#  block6f_se_reshape (Reshape)   (None, 1, 1, 1392)   0           ['block6f_se_squeeze[0][0]']
#
#  block6f_se_reduce (Conv2D)     (None, 1, 1, 58)     80794       ['block6f_se_reshape[0][0]']
#
#  block6f_se_expand (Conv2D)     (None, 1, 1, 1392)   82128       ['block6f_se_reduce[0][0]']
#
#  block6f_se_excite (Multiply)   (None, 4, 4, 1392)   0           ['block6f_activation[0][0]',
#                                                                   'block6f_se_expand[0][0]']
#
#  block6f_project_conv (Conv2D)  (None, 4, 4, 232)    322944      ['block6f_se_excite[0][0]']
#
#  block6f_project_bn (BatchNorma  (None, 4, 4, 232)   928         ['block6f_project_conv[0][0]']
#  lization)
#
#  block6f_drop (Dropout)         (None, 4, 4, 232)    0           ['block6f_project_bn[0][0]']
#
#  block6f_add (Add)              (None, 4, 4, 232)    0           ['block6f_drop[0][0]',
#                                                                   'block6e_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 4, 4, 1392)   322944      ['block6f_add[0][0]']
#
#  block7a_expand_bn (BatchNormal  (None, 4, 4, 1392)  5568        ['block7a_expand_conv[0][0]']
#  ization)
#
#  block7a_expand_activation (Act  (None, 4, 4, 1392)  0           ['block7a_expand_bn[0][0]']
#  ivation)
#
#  block7a_dwconv (DepthwiseConv2  (None, 4, 4, 1392)  12528       ['block7a_expand_activation[0][0]
#  D)                                                              ']
#
#  block7a_bn (BatchNormalization  (None, 4, 4, 1392)  5568        ['block7a_dwconv[0][0]']
#  )
#
#  block7a_activation (Activation  (None, 4, 4, 1392)  0           ['block7a_bn[0][0]']
#  )
#
#  block7a_se_squeeze (GlobalAver  (None, 1392)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1392)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 58)     80794       ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1392)   82128       ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 4, 4, 1392)   0           ['block7a_activation[0][0]',
#                                                                   'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 4, 4, 384)    534528      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 4, 4, 384)   1536        ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 4, 4, 2304)   884736      ['block7a_project_bn[0][0]']
#
#  block7b_expand_bn (BatchNormal  (None, 4, 4, 2304)  9216        ['block7b_expand_conv[0][0]']
#  ization)
#
#  block7b_expand_activation (Act  (None, 4, 4, 2304)  0           ['block7b_expand_bn[0][0]']
#  ivation)
#
#  block7b_dwconv (DepthwiseConv2  (None, 4, 4, 2304)  20736       ['block7b_expand_activation[0][0]
#  D)                                                              ']
#
#  block7b_bn (BatchNormalization  (None, 4, 4, 2304)  9216        ['block7b_dwconv[0][0]']
#  )
#
#  block7b_activation (Activation  (None, 4, 4, 2304)  0           ['block7b_bn[0][0]']
#  )
#
#  block7b_se_squeeze (GlobalAver  (None, 2304)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 2304)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 96)     221280      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 2304)   223488      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 4, 4, 2304)   0           ['block7b_activation[0][0]',
#                                                                   'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 4, 4, 384)    884736      ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 4, 4, 384)   1536        ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 4, 4, 384)    0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 4, 4, 384)    0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)              (None, 4, 4, 1536)   589824      ['block7b_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 4, 4, 1536)   6144        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 4, 4, 1536)   0           ['top_bn[0][0]']
#
#  flatten (Flatten)              (None, 24576)        0           ['top_activation[0][0]']
#
#  dense (Dense)                  (None, 25)           614425      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 11,397,960
# Trainable params: 614,425
# Non-trainable params: 10,783,535
# __________________________________________________________________________________________________

# %%
# Step 5: Model Training
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history=model.fit(X_train, y_train, epochs=30, validation_data=(X_validation, y_validation))
# Out:
# Epoch 1/30
# 2023-11-03 12:49:47.330571: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 350/350 [==============================] - 25s 43ms/step - loss: 0.2588 - accuracy: 0.9667 - val_loss: 1.6253 - val_accuracy: 0.8950
# Epoch 2/30
# 350/350 [==============================] - 12s 36ms/step - loss: 0.2814 - accuracy: 0.9656 - val_loss: 1.7888 - val_accuracy: 0.8914
# Epoch 3/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2999 - accuracy: 0.9639 - val_loss: 1.7022 - val_accuracy: 0.8961
# Epoch 4/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2597 - accuracy: 0.9697 - val_loss: 1.7406 - val_accuracy: 0.8950
# Epoch 5/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2640 - accuracy: 0.9718 - val_loss: 1.8015 - val_accuracy: 0.9021
# Epoch 6/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2705 - accuracy: 0.9709 - val_loss: 1.8741 - val_accuracy: 0.8925
# Epoch 7/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2797 - accuracy: 0.9686 - val_loss: 1.8293 - val_accuracy: 0.8914
# Epoch 8/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2542 - accuracy: 0.9689 - val_loss: 1.9532 - val_accuracy: 0.8889
# Epoch 9/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2193 - accuracy: 0.9745 - val_loss: 1.8142 - val_accuracy: 0.8975
# Epoch 10/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2463 - accuracy: 0.9749 - val_loss: 1.8310 - val_accuracy: 0.8993
# Epoch 11/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2294 - accuracy: 0.9742 - val_loss: 1.8345 - val_accuracy: 0.8993
# Epoch 12/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2420 - accuracy: 0.9723 - val_loss: 1.8915 - val_accuracy: 0.9018
# Epoch 13/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2264 - accuracy: 0.9764 - val_loss: 2.0001 - val_accuracy: 0.8904
# Epoch 14/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2319 - accuracy: 0.9735 - val_loss: 2.0500 - val_accuracy: 0.8921
# Epoch 15/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2429 - accuracy: 0.9748 - val_loss: 2.0364 - val_accuracy: 0.8946
# Epoch 16/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2388 - accuracy: 0.9748 - val_loss: 1.9305 - val_accuracy: 0.9029
# Epoch 17/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2280 - accuracy: 0.9751 - val_loss: 2.1157 - val_accuracy: 0.8875
# Epoch 18/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2195 - accuracy: 0.9783 - val_loss: 1.8730 - val_accuracy: 0.9025
# Epoch 19/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2390 - accuracy: 0.9740 - val_loss: 2.0554 - val_accuracy: 0.9007
# Epoch 20/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2372 - accuracy: 0.9750 - val_loss: 2.1951 - val_accuracy: 0.8954
# Epoch 21/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2340 - accuracy: 0.9744 - val_loss: 2.1454 - val_accuracy: 0.8950
# Epoch 22/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2616 - accuracy: 0.9763 - val_loss: 2.2882 - val_accuracy: 0.8896
# Epoch 23/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2495 - accuracy: 0.9743 - val_loss: 2.0811 - val_accuracy: 0.9011
# Epoch 24/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2381 - accuracy: 0.9768 - val_loss: 2.2702 - val_accuracy: 0.8986
# Epoch 25/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2505 - accuracy: 0.9784 - val_loss: 2.2289 - val_accuracy: 0.8954
# Epoch 26/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2292 - accuracy: 0.9786 - val_loss: 2.2184 - val_accuracy: 0.9018
# Epoch 27/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.1729 - accuracy: 0.9811 - val_loss: 2.3034 - val_accuracy: 0.8929
# Epoch 28/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2063 - accuracy: 0.9780 - val_loss: 2.3386 - val_accuracy: 0.8936
# Epoch 29/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.2060 - accuracy: 0.9806 - val_loss: 2.2180 - val_accuracy: 0.8914
# Epoch 30/30
# 350/350 [==============================] - 12s 35ms/step - loss: 0.1856 - accuracy: 0.9823 - val_loss: 2.2213 - val_accuracy: 0.8986

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from mlxtend.plotting import plot_confusion_matrix

# %%
y_pred=model.predict(X_test)
# Out:
# 110/110 [==============================] - 5s 29ms/step

# %%
y_pred2=np.argmax(y_pred, axis=1)
y_pred2
# Out:
# array([16, 15, 24, ...,  3, 19,  8])

# %%
y_test=np.argmax(y_test, axis=1)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 y_test=np.argmax(y_test, axis=1)
#
# File <__array_function__ internals>:180, in argmax(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/numpy/core/fromnumeric.py:1216, in argmax(a, axis, out, keepdims)
#    1129 """
#    1130 Returns the indices of the maximum values along an axis.
#    1131
#    (...)
#    1213 (2, 1, 4)
#    1214 """
#    1215 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1216 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File /opt/conda/lib/python3.10/site-packages/numpy/core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
confusion_matrix_result=confusion_matrix(y_test,y_pred2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt     
import pylab as pl
plt.title("skin detection")

ax= plt.subplot()
sns.heatmap(confusion_matrix_result, annot=True, fmt='g', ax=ax);
pl.show()

# %%
import os
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Convolution2D, ZeroPadding2D,MaxPooling2D, Flatten, Dense, Dropout, Activation
from PIL import Image
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, save_img, img_to_array
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.preprocessing import image
import pandas as pd
import tensorflow as tf
import keras
import pickle

# %%
confusion_matrix=classification_report(y_test,y_pred2)

# %%
print(confusion_matrix)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92       128
#            1       0.94      0.93      0.94       137
#            2       0.91      0.95      0.93       131
#            3       0.95      0.89      0.92       121
#            4       0.96      0.90      0.93       135
#            5       0.92      0.94      0.93       131
#            6       0.93      0.86      0.89       153
#            7       0.88      0.92      0.90       140
#            8       0.99      0.86      0.92       132
#            9       0.72      0.86      0.78       148
#           10       0.93      0.87      0.90       142
#           11       0.88      0.92      0.90       149
#           12       0.98      1.00      0.99       124
#           13       0.84      0.76      0.80       140
#           14       0.87      0.92      0.89       143
#           15       0.91      0.97      0.94       152
#           16       0.81      0.92      0.86       148
#           17       0.91      0.94      0.92       159
#           18       0.96      0.92      0.94       145
#           19       0.99      0.98      0.99       136
#           20       0.98      0.92      0.95       148
#           21       0.91      0.90      0.91       154
#           22       0.94      0.92      0.93       126
#           23       0.91      0.93      0.92       141
#           24       0.92      0.83      0.87       137
#
#     accuracy                           0.91      3500
#    macro avg       0.91      0.91      0.91      3500
# weighted avg       0.91      0.91      0.91      3500

# %%
train_accuracy = history.history['accuracy']
#val_accuracy = history.history['val_accuracy']
train_loss = history.history['loss']
#val_loss = history.history['val_loss']

epochs = range(len(train_accuracy))
plt.figure(figsize=(12,4))
# Plotting the accuracy
plt.subplot(1,2,1)
plt.plot(epochs, train_accuracy, 'b', label='Training accuracy')

plt.title('Training accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train', 'val'], loc='lower right')

# Plotting the loss
plt.subplot(1,2,2)
plt.plot(epochs, train_loss, 'b', label='Training loss')

plt.title('Loss accuracy')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['train', 'val'], loc='upper right')

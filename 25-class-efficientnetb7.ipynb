# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        pass
        #print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
import random
from PIL import Image
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras import Sequential, Model
from keras.layers import (Conv2D, MaxPooling2D, Dense, Flatten, \
                          Dropout, Input,GlobalAveragePooling2D,BatchNormalization)
from tensorflow.keras.activations import softmax
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from mpl_toolkits.axes_grid1 import ImageGrid
from keras.models import Model
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import (ConfusionMatrixDisplay, confusion_matrix, 
                             accuracy_score)
import cv2
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import os
trainOne=os.listdir('/kaggle/input/skindatasets/skin/train')
trainTow=os.listdir("/kaggle/input/dateset-23-skin/dataset")
cat=trainTow
cat2=['Normal','vitiligo']
def data_dictionary():
    path_trainOne="/kaggle/input/dateset-23-skin/dataset/"
    path_trainTow="/kaggle/input/skindatasets/skin/train/"
    list_train=cat
    list_train1=cat2
    train_dictionary={"image_path":[],"target":[]}
    test_dictionary={"image_path":[],"target":[]}
    k=0
    for i in list_train:
        print(i)
        path_disease_train=path_trainOne+i
        image_list_train=os.listdir(path_disease_train)
        for j in image_list_train:
            img_path_train=path_disease_train+"/"+j   
            train_dictionary["image_path"].append(img_path_train)
            train_dictionary['target'].append(k)
                
        k+=1
    L=23    
    for i in list_train1:
       
        path_disease_test=path_trainTow+i
        image_list_test=os.listdir(path_disease_test)
        for j in image_list_test:
            img_path_train=path_disease_test+"/"+j
            if img_path_train!="/kaggle/input/skindatasets/skin/train/Normal/34.avif":
                
            #print(img_path_train)
                train_dictionary["image_path"].append(img_path_train)
                train_dictionary['target'].append(L)
        L+=1    
          
    train_df=pd.DataFrame(train_dictionary)
    train_df = train_df.groupby("target").head(700) 
    
    return  train_df

# %%
train=data_dictionary()
# Out:
# Light Diseases and Disorders of Pigmentation
# Lupus and other Connective Tissue diseases
# Acne and Rosacea Photos
# Systemic Disease
# Poison Ivy Photos and other Contact Dermatitis
# Vascular Tumors
# Urticaria Hives
# Atopic Dermatitis Photos
# Bullous Disease Photos
# Hair Loss Photos Alopecia and other Hair Diseases
# Tinea Ringworm Candidiasis and other Fungal Infections
# Psoriasis pictures Lichen Planus and related diseases
# Melanoma Skin Cancer Nevi and Moles
# Nail Fungus and other Nail Disease
# Scabies Lyme Disease and other Infestations and Bites
# Eczema Photos
# Exanthems and Drug Eruptions
# Herpes HPV and other STDs Photos
# Seborrheic Keratoses and other Benign Tumors
# Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions
# Vasculitis Photos
# Cellulitis Impetigo and other Bacterial Infections
# Warts Molluscum and other Viral Infections

# %%
import cv2
images=[]
label=[]
for i in train['image_path']:
    img=cv2.imread(i)
    img=cv2.resize(img,(100,100),interpolation=cv2.INTER_AREA)
    img = cv2.normalize(img, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8U)
    #img=resize_and_rescale(img)
    images.append(img)

# %%
label=train['target']

# %%
import numpy as np
import pandas as pd

# %%
data=np.array(images)

# %%
label=np.array(label)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.2,random_state=44)
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=0.2,random_state=1)

# %%
X_train.shape
# Out:
# (11200, 100, 100, 3)

# %%
X_test.shape
# Out:
# (3500, 100, 100, 3)

# %%
import keras
num_classes = 25
y_train = keras.utils.to_categorical(y_train, num_classes)

# %%
y_validation=keras.utils.to_categorical(y_validation, num_classes)

# %%
y_test=keras.utils.to_categorical(y_test, num_classes)

# %%
from tensorflow.keras.applications import  VGG19,EfficientNetB0,VGG16,InceptionV3,ResNet50,EfficientNetB3
from tensorflow.keras.models import Model
from keras.applications.vgg16 import preprocess_input

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50,EfficientNetB7
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.models import Model
# Step 1: Choose a Pre-trained Model
base_model = EfficientNetB7(weights='imagenet', include_top=False, input_shape=(100, 100, 3))
# Step 2: Model Modification
x = base_model.output
x = Flatten()(x)
# x = BatchNormalization()(x)
# x = MaxPooling2D(pool_size=(2, 2))(x)
# x = Flatten()(x)
# x = Dense(256, activation='relu')(x)
# x = BatchNormalization()(x)
# x = Dense(128, activation='relu')(x)
# x = Flatten()(x)
# x = BatchNormalization()(x)
# x = Dense(64, activation='relu')(x)

predictions = Dense(25, activation='softmax')(x)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258076736/258076736 [==============================] - 1s 0us/step

# %%
model = Model(inputs=base_model.input, outputs=predictions)
# Step 3: Freeze Pre-trained Layers
for layer in base_model.layers:
    layer.trainable = False

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 100, 100, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 100, 100, 3)  7           ['rescaling[0][0]']
#
#  rescaling_1 (Rescaling)        (None, 100, 100, 3)  0           ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 101, 101, 3)  0           ['rescaling_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 50, 50, 64)   1728        ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 50, 50, 64)   256         ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 50, 50, 64)   0           ['stem_bn[0][0]']
#
#  block1a_dwconv (DepthwiseConv2  (None, 50, 50, 64)  576         ['stem_activation[0][0]']
#  D)
#
#  block1a_bn (BatchNormalization  (None, 50, 50, 64)  256         ['block1a_dwconv[0][0]']
#  )
#
#  block1a_activation (Activation  (None, 50, 50, 64)  0           ['block1a_bn[0][0]']
#  )
#
#  block1a_se_squeeze (GlobalAver  (None, 64)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 64)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 16)     1040        ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 64)     1088        ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 50, 50, 64)   0           ['block1a_activation[0][0]',
#                                                                   'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 50, 50, 32)   2048        ['block1a_se_excite[0][0]']
#
#  block1a_project_bn (BatchNorma  (None, 50, 50, 32)  128         ['block1a_project_conv[0][0]']
#  lization)
#
#  block1b_dwconv (DepthwiseConv2  (None, 50, 50, 32)  288         ['block1a_project_bn[0][0]']
#  D)
#
#  block1b_bn (BatchNormalization  (None, 50, 50, 32)  128         ['block1b_dwconv[0][0]']
#  )
#
#  block1b_activation (Activation  (None, 50, 50, 32)  0           ['block1b_bn[0][0]']
#  )
#
#  block1b_se_squeeze (GlobalAver  (None, 32)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 50, 50, 32)   0           ['block1b_activation[0][0]',
#                                                                   'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 50, 50, 32)   1024        ['block1b_se_excite[0][0]']
#
#  block1b_project_bn (BatchNorma  (None, 50, 50, 32)  128         ['block1b_project_conv[0][0]']
#  lization)
#
#  block1b_drop (Dropout)         (None, 50, 50, 32)   0           ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)              (None, 50, 50, 32)   0           ['block1b_drop[0][0]',
#                                                                   'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseConv2  (None, 50, 50, 32)  288         ['block1b_add[0][0]']
#  D)
#
#  block1c_bn (BatchNormalization  (None, 50, 50, 32)  128         ['block1c_dwconv[0][0]']
#  )
#
#  block1c_activation (Activation  (None, 50, 50, 32)  0           ['block1c_bn[0][0]']
#  )
#
#  block1c_se_squeeze (GlobalAver  (None, 32)          0           ['block1c_activation[0][0]']
#  agePooling2D)
#
#  block1c_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1c_se_squeeze[0][0]']
#
#  block1c_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multiply)   (None, 50, 50, 32)   0           ['block1c_activation[0][0]',
#                                                                   'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 50, 50, 32)   1024        ['block1c_se_excite[0][0]']
#
#  block1c_project_bn (BatchNorma  (None, 50, 50, 32)  128         ['block1c_project_conv[0][0]']
#  lization)
#
#  block1c_drop (Dropout)         (None, 50, 50, 32)   0           ['block1c_project_bn[0][0]']
#
#  block1c_add (Add)              (None, 50, 50, 32)   0           ['block1c_drop[0][0]',
#                                                                   'block1b_add[0][0]']
#
#  block1d_dwconv (DepthwiseConv2  (None, 50, 50, 32)  288         ['block1c_add[0][0]']
#  D)
#
#  block1d_bn (BatchNormalization  (None, 50, 50, 32)  128         ['block1d_dwconv[0][0]']
#  )
#
#  block1d_activation (Activation  (None, 50, 50, 32)  0           ['block1d_bn[0][0]']
#  )
#
#  block1d_se_squeeze (GlobalAver  (None, 32)          0           ['block1d_activation[0][0]']
#  agePooling2D)
#
#  block1d_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1d_se_squeeze[0][0]']
#
#  block1d_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1d_se_reshape[0][0]']
#
#  block1d_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1d_se_reduce[0][0]']
#
#  block1d_se_excite (Multiply)   (None, 50, 50, 32)   0           ['block1d_activation[0][0]',
#                                                                   'block1d_se_expand[0][0]']
#
#  block1d_project_conv (Conv2D)  (None, 50, 50, 32)   1024        ['block1d_se_excite[0][0]']
#
#  block1d_project_bn (BatchNorma  (None, 50, 50, 32)  128         ['block1d_project_conv[0][0]']
#  lization)
#
#  block1d_drop (Dropout)         (None, 50, 50, 32)   0           ['block1d_project_bn[0][0]']
#
#  block1d_add (Add)              (None, 50, 50, 32)   0           ['block1d_drop[0][0]',
#                                                                   'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 50, 50, 192)  6144        ['block1d_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 50, 50, 192)  768        ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 50, 50, 192)  0          ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 51, 51, 192)  0          ['block2a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 25, 25, 192)  1728       ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 25, 25, 192)  768        ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 25, 25, 192)  0          ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 192)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 25, 25, 192)  0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 25, 25, 48)   9216        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 25, 25, 48)  192         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 25, 25, 288)  13824       ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 25, 25, 288)  1152       ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 25, 25, 288)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 25, 25, 288)  2592       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 25, 25, 288)  1152       ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 25, 25, 288)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 288)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 25, 25, 288)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 25, 25, 48)   13824       ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 25, 25, 48)  192         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 25, 25, 48)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 25, 25, 48)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 25, 25, 288)  13824       ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 25, 25, 288)  1152       ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 25, 25, 288)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 25, 25, 288)  2592       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 25, 25, 288)  1152       ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 25, 25, 288)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 288)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 25, 25, 288)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 25, 25, 48)   13824       ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 25, 25, 48)  192         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 25, 25, 48)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 25, 25, 48)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 25, 25, 288)  13824       ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 25, 25, 288)  1152       ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 25, 25, 288)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_dwconv (DepthwiseConv2  (None, 25, 25, 288)  2592       ['block2d_expand_activation[0][0]
#  D)                                                              ']
#
#  block2d_bn (BatchNormalization  (None, 25, 25, 288)  1152       ['block2d_dwconv[0][0]']
#  )
#
#  block2d_activation (Activation  (None, 25, 25, 288)  0          ['block2d_bn[0][0]']
#  )
#
#  block2d_se_squeeze (GlobalAver  (None, 288)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 25, 25, 288)  0           ['block2d_activation[0][0]',
#                                                                   'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 25, 25, 48)   13824       ['block2d_se_excite[0][0]']
#
#  block2d_project_bn (BatchNorma  (None, 25, 25, 48)  192         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (Dropout)         (None, 25, 25, 48)   0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 25, 25, 48)   0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 25, 25, 288)  13824       ['block2d_add[0][0]']
#
#  block2e_expand_bn (BatchNormal  (None, 25, 25, 288)  1152       ['block2e_expand_conv[0][0]']
#  ization)
#
#  block2e_expand_activation (Act  (None, 25, 25, 288)  0          ['block2e_expand_bn[0][0]']
#  ivation)
#
#  block2e_dwconv (DepthwiseConv2  (None, 25, 25, 288)  2592       ['block2e_expand_activation[0][0]
#  D)                                                              ']
#
#  block2e_bn (BatchNormalization  (None, 25, 25, 288)  1152       ['block2e_dwconv[0][0]']
#  )
#
#  block2e_activation (Activation  (None, 25, 25, 288)  0          ['block2e_bn[0][0]']
#  )
#
#  block2e_se_squeeze (GlobalAver  (None, 288)         0           ['block2e_activation[0][0]']
#  agePooling2D)
#
#  block2e_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2e_se_squeeze[0][0]']
#
#  block2e_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multiply)   (None, 25, 25, 288)  0           ['block2e_activation[0][0]',
#                                                                   'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv2D)  (None, 25, 25, 48)   13824       ['block2e_se_excite[0][0]']
#
#  block2e_project_bn (BatchNorma  (None, 25, 25, 48)  192         ['block2e_project_conv[0][0]']
#  lization)
#
#  block2e_drop (Dropout)         (None, 25, 25, 48)   0           ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)              (None, 25, 25, 48)   0           ['block2e_drop[0][0]',
#                                                                   'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2D)   (None, 25, 25, 288)  13824       ['block2e_add[0][0]']
#
#  block2f_expand_bn (BatchNormal  (None, 25, 25, 288)  1152       ['block2f_expand_conv[0][0]']
#  ization)
#
#  block2f_expand_activation (Act  (None, 25, 25, 288)  0          ['block2f_expand_bn[0][0]']
#  ivation)
#
#  block2f_dwconv (DepthwiseConv2  (None, 25, 25, 288)  2592       ['block2f_expand_activation[0][0]
#  D)                                                              ']
#
#  block2f_bn (BatchNormalization  (None, 25, 25, 288)  1152       ['block2f_dwconv[0][0]']
#  )
#
#  block2f_activation (Activation  (None, 25, 25, 288)  0          ['block2f_bn[0][0]']
#  )
#
#  block2f_se_squeeze (GlobalAver  (None, 288)         0           ['block2f_activation[0][0]']
#  agePooling2D)
#
#  block2f_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2f_se_squeeze[0][0]']
#
#  block2f_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2f_se_reshape[0][0]']
#
#  block2f_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2f_se_reduce[0][0]']
#
#  block2f_se_excite (Multiply)   (None, 25, 25, 288)  0           ['block2f_activation[0][0]',
#                                                                   'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv2D)  (None, 25, 25, 48)   13824       ['block2f_se_excite[0][0]']
#
#  block2f_project_bn (BatchNorma  (None, 25, 25, 48)  192         ['block2f_project_conv[0][0]']
#  lization)
#
#  block2f_drop (Dropout)         (None, 25, 25, 48)   0           ['block2f_project_bn[0][0]']
#
#  block2f_add (Add)              (None, 25, 25, 48)   0           ['block2f_drop[0][0]',
#                                                                   'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2D)   (None, 25, 25, 288)  13824       ['block2f_add[0][0]']
#
#  block2g_expand_bn (BatchNormal  (None, 25, 25, 288)  1152       ['block2g_expand_conv[0][0]']
#  ization)
#
#  block2g_expand_activation (Act  (None, 25, 25, 288)  0          ['block2g_expand_bn[0][0]']
#  ivation)
#
#  block2g_dwconv (DepthwiseConv2  (None, 25, 25, 288)  2592       ['block2g_expand_activation[0][0]
#  D)                                                              ']
#
#  block2g_bn (BatchNormalization  (None, 25, 25, 288)  1152       ['block2g_dwconv[0][0]']
#  )
#
#  block2g_activation (Activation  (None, 25, 25, 288)  0          ['block2g_bn[0][0]']
#  )
#
#  block2g_se_squeeze (GlobalAver  (None, 288)         0           ['block2g_activation[0][0]']
#  agePooling2D)
#
#  block2g_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2g_se_squeeze[0][0]']
#
#  block2g_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2g_se_reshape[0][0]']
#
#  block2g_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2g_se_reduce[0][0]']
#
#  block2g_se_excite (Multiply)   (None, 25, 25, 288)  0           ['block2g_activation[0][0]',
#                                                                   'block2g_se_expand[0][0]']
#
#  block2g_project_conv (Conv2D)  (None, 25, 25, 48)   13824       ['block2g_se_excite[0][0]']
#
#  block2g_project_bn (BatchNorma  (None, 25, 25, 48)  192         ['block2g_project_conv[0][0]']
#  lization)
#
#  block2g_drop (Dropout)         (None, 25, 25, 48)   0           ['block2g_project_bn[0][0]']
#
#  block2g_add (Add)              (None, 25, 25, 48)   0           ['block2g_drop[0][0]',
#                                                                   'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 25, 25, 288)  13824       ['block2g_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 25, 25, 288)  1152       ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 25, 25, 288)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 29, 29, 288)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 13, 13, 288)  7200       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 13, 13, 288)  1152       ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 13, 13, 288)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 288)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 13, 13, 288)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 13, 13, 80)   23040       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 13, 13, 80)  320         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 13, 13, 480)  38400       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 13, 13, 480)  1920       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 13, 13, 480)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 13, 13, 480)  12000      ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 13, 13, 480)  1920       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 13, 13, 480)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 480)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 13, 13, 480)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 13, 13, 80)   38400       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 13, 13, 80)  320         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 13, 13, 80)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 13, 13, 80)   0           ['block3b_drop[0][0]',
# ...
#  ization)
#
#  block7a_expand_activation (Act  (None, 4, 4, 2304)  0           ['block7a_expand_bn[0][0]']
#  ivation)
#
#  block7a_dwconv (DepthwiseConv2  (None, 4, 4, 2304)  20736       ['block7a_expand_activation[0][0]
#  D)                                                              ']
#
#  block7a_bn (BatchNormalization  (None, 4, 4, 2304)  9216        ['block7a_dwconv[0][0]']
#  )
#
#  block7a_activation (Activation  (None, 4, 4, 2304)  0           ['block7a_bn[0][0]']
#  )
#
#  block7a_se_squeeze (GlobalAver  (None, 2304)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 2304)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 96)     221280      ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 2304)   223488      ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 4, 4, 2304)   0           ['block7a_activation[0][0]',
#                                                                   'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 4, 4, 640)    1474560     ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 4, 4, 640)   2560        ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 4, 4, 3840)   2457600     ['block7a_project_bn[0][0]']
#
#  block7b_expand_bn (BatchNormal  (None, 4, 4, 3840)  15360       ['block7b_expand_conv[0][0]']
#  ization)
#
#  block7b_expand_activation (Act  (None, 4, 4, 3840)  0           ['block7b_expand_bn[0][0]']
#  ivation)
#
#  block7b_dwconv (DepthwiseConv2  (None, 4, 4, 3840)  34560       ['block7b_expand_activation[0][0]
#  D)                                                              ']
#
#  block7b_bn (BatchNormalization  (None, 4, 4, 3840)  15360       ['block7b_dwconv[0][0]']
#  )
#
#  block7b_activation (Activation  (None, 4, 4, 3840)  0           ['block7b_bn[0][0]']
#  )
#
#  block7b_se_squeeze (GlobalAver  (None, 3840)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 4, 4, 3840)   0           ['block7b_activation[0][0]',
#                                                                   'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 4, 4, 640)    2457600     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 4, 4, 640)   2560        ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 4, 4, 640)    0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 4, 4, 640)    0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2D)   (None, 4, 4, 3840)   2457600     ['block7b_add[0][0]']
#
#  block7c_expand_bn (BatchNormal  (None, 4, 4, 3840)  15360       ['block7c_expand_conv[0][0]']
#  ization)
#
#  block7c_expand_activation (Act  (None, 4, 4, 3840)  0           ['block7c_expand_bn[0][0]']
#  ivation)
#
#  block7c_dwconv (DepthwiseConv2  (None, 4, 4, 3840)  34560       ['block7c_expand_activation[0][0]
#  D)                                                              ']
#
#  block7c_bn (BatchNormalization  (None, 4, 4, 3840)  15360       ['block7c_dwconv[0][0]']
#  )
#
#  block7c_activation (Activation  (None, 4, 4, 3840)  0           ['block7c_bn[0][0]']
#  )
#
#  block7c_se_squeeze (GlobalAver  (None, 3840)        0           ['block7c_activation[0][0]']
#  agePooling2D)
#
#  block7c_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7c_se_squeeze[0][0]']
#
#  block7c_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multiply)   (None, 4, 4, 3840)   0           ['block7c_activation[0][0]',
#                                                                   'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv2D)  (None, 4, 4, 640)    2457600     ['block7c_se_excite[0][0]']
#
#  block7c_project_bn (BatchNorma  (None, 4, 4, 640)   2560        ['block7c_project_conv[0][0]']
#  lization)
#
#  block7c_drop (Dropout)         (None, 4, 4, 640)    0           ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)              (None, 4, 4, 640)    0           ['block7c_drop[0][0]',
#                                                                   'block7b_add[0][0]']
#
#  block7d_expand_conv (Conv2D)   (None, 4, 4, 3840)   2457600     ['block7c_add[0][0]']
#
#  block7d_expand_bn (BatchNormal  (None, 4, 4, 3840)  15360       ['block7d_expand_conv[0][0]']
#  ization)
#
#  block7d_expand_activation (Act  (None, 4, 4, 3840)  0           ['block7d_expand_bn[0][0]']
#  ivation)
#
#  block7d_dwconv (DepthwiseConv2  (None, 4, 4, 3840)  34560       ['block7d_expand_activation[0][0]
#  D)                                                              ']
#
#  block7d_bn (BatchNormalization  (None, 4, 4, 3840)  15360       ['block7d_dwconv[0][0]']
#  )
#
#  block7d_activation (Activation  (None, 4, 4, 3840)  0           ['block7d_bn[0][0]']
#  )
#
#  block7d_se_squeeze (GlobalAver  (None, 3840)        0           ['block7d_activation[0][0]']
#  agePooling2D)
#
#  block7d_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7d_se_squeeze[0][0]']
#
#  block7d_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multiply)   (None, 4, 4, 3840)   0           ['block7d_activation[0][0]',
#                                                                   'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv2D)  (None, 4, 4, 640)    2457600     ['block7d_se_excite[0][0]']
#
#  block7d_project_bn (BatchNorma  (None, 4, 4, 640)   2560        ['block7d_project_conv[0][0]']
#  lization)
#
#  block7d_drop (Dropout)         (None, 4, 4, 640)    0           ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)              (None, 4, 4, 640)    0           ['block7d_drop[0][0]',
#                                                                   'block7c_add[0][0]']
#
#  top_conv (Conv2D)              (None, 4, 4, 2560)   1638400     ['block7d_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 4, 4, 2560)   10240       ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 4, 4, 2560)   0           ['top_bn[0][0]']
#
#  flatten (Flatten)              (None, 40960)        0           ['top_activation[0][0]']
#
#  dense (Dense)                  (None, 25)           1024025     ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 65,121,712
# Trainable params: 1,024,025
# Non-trainable params: 64,097,687
# __________________________________________________________________________________________________

# %%
# Step 5: Model Training
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history=model.fit(X_train, y_train, epochs=30, validation_data=(X_validation, y_validation))
# Out:
# Epoch 1/30
# 2023-11-03 15:27:21.659281: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 350/350 [==============================] - 76s 133ms/step - loss: 3.8341 - accuracy: 0.3749 - val_loss: 2.8912 - val_accuracy: 0.4986
# Epoch 2/30
# 350/350 [==============================] - 40s 114ms/step - loss: 2.4428 - accuracy: 0.5788 - val_loss: 2.1260 - val_accuracy: 0.6339
# Epoch 3/30
# 350/350 [==============================] - 40s 116ms/step - loss: 1.7602 - accuracy: 0.6857 - val_loss: 1.9100 - val_accuracy: 0.6614
# Epoch 4/30
# 350/350 [==============================] - 40s 115ms/step - loss: 1.6901 - accuracy: 0.7098 - val_loss: 1.7059 - val_accuracy: 0.7168
# Epoch 5/30
# 350/350 [==============================] - 40s 116ms/step - loss: 1.3268 - accuracy: 0.7632 - val_loss: 1.7036 - val_accuracy: 0.7304
# Epoch 6/30
# 350/350 [==============================] - 40s 116ms/step - loss: 1.1081 - accuracy: 0.8005 - val_loss: 1.6731 - val_accuracy: 0.7561
# Epoch 7/30
# 350/350 [==============================] - 40s 116ms/step - loss: 1.3118 - accuracy: 0.7900 - val_loss: 1.8156 - val_accuracy: 0.7468
# Epoch 8/30
# 350/350 [==============================] - 40s 116ms/step - loss: 1.1573 - accuracy: 0.8134 - val_loss: 1.7134 - val_accuracy: 0.7675
# Epoch 9/30
# 350/350 [==============================] - 40s 116ms/step - loss: 1.1519 - accuracy: 0.8183 - val_loss: 1.8839 - val_accuracy: 0.7711
# Epoch 10/30
# 350/350 [==============================] - 40s 116ms/step - loss: 1.1009 - accuracy: 0.8313 - val_loss: 1.3151 - val_accuracy: 0.8143
# Epoch 11/30
# 350/350 [==============================] - 40s 116ms/step - loss: 0.7270 - accuracy: 0.8708 - val_loss: 1.1744 - val_accuracy: 0.8336
# Epoch 12/30
# 350/350 [==============================] - 40s 115ms/step - loss: 0.9858 - accuracy: 0.8471 - val_loss: 1.5155 - val_accuracy: 0.8246
# Epoch 13/30
# 350/350 [==============================] - 40s 116ms/step - loss: 0.9189 - accuracy: 0.8577 - val_loss: 1.6233 - val_accuracy: 0.8079
# Epoch 14/30
# 350/350 [==============================] - 40s 116ms/step - loss: 0.8297 - accuracy: 0.8743 - val_loss: 2.0086 - val_accuracy: 0.7886
# Epoch 15/30
# 350/350 [==============================] - 40s 115ms/step - loss: 0.7702 - accuracy: 0.8830 - val_loss: 1.9943 - val_accuracy: 0.7939
# Epoch 16/30
# 350/350 [==============================] - 40s 116ms/step - loss: 0.9625 - accuracy: 0.8652 - val_loss: 1.8509 - val_accuracy: 0.8043
# Epoch 17/30
# 350/350 [==============================] - 40s 116ms/step - loss: 0.7377 - accuracy: 0.8853 - val_loss: 1.8748 - val_accuracy: 0.8075
# Epoch 18/30
# 350/350 [==============================] - 40s 115ms/step - loss: 0.8260 - accuracy: 0.8858 - val_loss: 2.0694 - val_accuracy: 0.8054
# Epoch 19/30
# 350/350 [==============================] - 40s 116ms/step - loss: 0.8188 - accuracy: 0.8860 - val_loss: 2.1966 - val_accuracy: 0.7754
# Epoch 20/30
# 350/350 [==============================] - 40s 115ms/step - loss: 0.9527 - accuracy: 0.8823 - val_loss: 1.7732 - val_accuracy: 0.8457
# Epoch 21/30
# 350/350 [==============================] - 40s 115ms/step - loss: 0.7352 - accuracy: 0.8971 - val_loss: 2.1180 - val_accuracy: 0.8079
# Epoch 22/30
# 350/350 [==============================] - 40s 116ms/step - loss: 0.6974 - accuracy: 0.9040 - val_loss: 1.4921 - val_accuracy: 0.8496
# Epoch 23/30
# 350/350 [==============================] - 40s 116ms/step - loss: 0.8006 - accuracy: 0.8982 - val_loss: 1.5418 - val_accuracy: 0.8554
# Epoch 24/30
# 350/350 [==============================] - 40s 116ms/step - loss: 0.8130 - accuracy: 0.9024 - val_loss: 1.6198 - val_accuracy: 0.8600
# Epoch 25/30
# 350/350 [==============================] - 40s 116ms/step - loss: 0.6634 - accuracy: 0.9138 - val_loss: 1.4860 - val_accuracy: 0.8629
# Epoch 26/30
# 350/350 [==============================] - 40s 116ms/step - loss: 0.5798 - accuracy: 0.9212 - val_loss: 2.1618 - val_accuracy: 0.8204
# Epoch 27/30
# 350/350 [==============================] - 40s 115ms/step - loss: 0.7261 - accuracy: 0.9100 - val_loss: 2.3022 - val_accuracy: 0.7943
# Epoch 28/30
# 350/350 [==============================] - 40s 115ms/step - loss: 0.7967 - accuracy: 0.9029 - val_loss: 2.3921 - val_accuracy: 0.8179
# Epoch 29/30
# 350/350 [==============================] - 40s 115ms/step - loss: 0.7532 - accuracy: 0.9079 - val_loss: 1.6357 - val_accuracy: 0.8686
# Epoch 30/30
# 350/350 [==============================] - 40s 116ms/step - loss: 0.5832 - accuracy: 0.9231 - val_loss: 1.6662 - val_accuracy: 0.8654

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from mlxtend.plotting import plot_confusion_matrix

# %%
y_pred=model.predict(X_test)
# Out:
# 110/110 [==============================] - 17s 103ms/step

# %%
y_pred2=np.argmax(y_pred, axis=1)
y_pred2
# Out:
# array([16, 15, 24, ..., 17, 19,  8])

# %%
y_test=np.argmax(y_test, axis=1)

# %%
confusion_matrix_result=confusion_matrix(y_test,y_pred2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt     
import pylab as pl
plt.title("skin detection")

ax= plt.subplot()
sns.heatmap(confusion_matrix_result, annot=True, fmt='g', ax=ax);
pl.show()

# %%
import os
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Convolution2D, ZeroPadding2D,MaxPooling2D, Flatten, Dense, Dropout, Activation
from PIL import Image
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, save_img, img_to_array
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.preprocessing import image
import pandas as pd
import tensorflow as tf
import keras
import pickle

# %%
confusion_matrix=classification_report(y_test,y_pred2)

# %%
print(confusion_matrix)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.87      0.91       128
#            1       0.98      0.82      0.90       137
#            2       0.83      0.94      0.88       131
#            3       0.95      0.89      0.92       121
#            4       0.80      0.96      0.87       135
#            5       0.97      0.78      0.86       131
#            6       0.73      0.92      0.81       153
#            7       0.77      0.94      0.84       140
#            8       0.76      0.93      0.84       132
#            9       0.77      0.83      0.80       148
#           10       0.89      0.91      0.90       142
#           11       1.00      0.72      0.84       149
#           12       0.98      0.95      0.97       124
#           13       0.77      0.79      0.78       140
#           14       0.81      0.92      0.86       143
#           15       0.96      0.85      0.90       152
#           16       0.97      0.87      0.92       148
#           17       0.84      0.96      0.90       159
#           18       1.00      0.81      0.90       145
#           19       0.98      0.98      0.98       136
#           20       0.81      0.96      0.88       148
#           21       0.93      0.82      0.87       154
#           22       0.94      0.87      0.91       126
#           23       0.91      0.82      0.86       141
#           24       0.89      0.77      0.82       137
#
#     accuracy                           0.87      3500
#    macro avg       0.89      0.87      0.88      3500
# weighted avg       0.89      0.87      0.88      3500

# %%
train_accuracy = history.history['accuracy']
#val_accuracy = history.history['val_accuracy']
train_loss = history.history['loss']
#val_loss = history.history['val_loss']

epochs = range(len(train_accuracy))
plt.figure(figsize=(12,4))
# Plotting the accuracy
plt.subplot(1,2,1)
plt.plot(epochs, train_accuracy, 'b', label='Training accuracy')

plt.title('Training accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train', 'val'], loc='lower right')

# Plotting the loss
plt.subplot(1,2,2)
plt.plot(epochs, train_loss, 'b', label='Training loss')

plt.title('Loss accuracy')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['train', 'val'], loc='upper right')
